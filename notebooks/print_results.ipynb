# %% [markdown]
# ## Expected Accuracy

# %%
import os
import json
import pandas as pd

def get_acc(dataset_name: str, model_name: str) -> float:
    filepath = f"../outputs/{dataset_name}__{model_name}/ground_truth_summary.json"
    if not os.path.exists(filepath):
        return None
    with open(filepath, "r") as f:
        data = json.load(f)
    return data["mean_accuracy"]

dataset_names = ["triviaqa-validation", "simpleqa-verified", "gsm8k-test", "math-500", "aime25-test", "mmlu-validation", "gpqa-diamond"]
model_names = ["Olmo-3-7B-Instruct", "Qwen3-8B-non-thinking", "gpt-oss-20b"]

import pandas as pd

# Construct a DataFrame with model_names as rows, dataset_names as columns, and values are accs
acc_matrix = []
for model in model_names:
    row = []
    for dataset in dataset_names:
        acc = get_acc(dataset, model)
        row.append(acc)
    acc_matrix.append(row)

df = pd.DataFrame(acc_matrix, index=model_names, columns=dataset_names)
df
# Out:
#                        triviaqa-validation  simpleqa-verified  gsm8k-test  \
# Olmo-3-7B-Instruct                0.488363           0.033590    0.933131
# Qwen3-8B-non-thinking             0.603952           0.052145    0.935641
# gpt-oss-20b                       0.650733           0.060100    0.957566
#
#                        math-500  aime25-test  mmlu-validation  gpqa-diamond
# Olmo-3-7B-Instruct      0.90056     0.411333         0.704572      0.436414
# Qwen3-8B-non-thinking   0.82964     0.203667         0.793965      0.496465
# gpt-oss-20b             0.95662     0.739113         0.893788           NaN
